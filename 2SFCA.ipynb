# %%
import geopandas as gpd
import pandas as pd
import numpy as np
from shapely.geometry import Point
from scipy.spatial import cKDTree
from pyproj import Proj, transform
from pyproj import Transformer
from tqdm import tqdm

def transform_5179_to_4326(x, y):
    # Transformer 객체 생성
    transformer = Transformer.from_crs("epsg:5179", "epsg:4326", always_xy=True)
    # 좌표 변환
    lon, lat = transformer.transform(x, y)
    return lat, lon

def transform_2097_to_4326(x, y):
    # Transformer 객체 생성
    transformer = Transformer.from_crs("epsg:2097", "epsg:4326", always_xy=True)
    # 좌표 변환
    lon, lat = transformer.transform(x, y)
    return lat, lon

def transform_2097_to_5179(x, y):
    # Transformer 객체 생성
    transformer = Transformer.from_crs("epsg:2097", "epsg:5179", always_xy=True)
    # 좌표 변환
    lon, lat = transformer.transform(x, y)
    return lat, lon

def transform_3857_to_4326(x, y):
    # Transformer 객체 생성
    transformer = Transformer.from_crs("epsg:3857", "epsg:4326", always_xy=True)
    # 좌표 변환
    lon, lat = transformer.transform(x, y)
    return lat, lon



# 1. 격자 구조 인구밀도 데이터 -> 중심점 계산
def calculate_centroids(grid_df):
    grid_df['centroid'] = grid_df.geometry.centroid
    return grid_df

# 2. 좌표 체계 맞추기
def align_crs(grid_df, shops_gdf):
    # 격자 데이터 CRS 설정 (EPSG:5181 사용)
    if grid_df.crs is None:
        grid_df = grid_df.set_crs(epsg=5181, allow_override=True)
    
    # 상점 데이터 CRS 설정 (EPSG:4326 사용)
    if shops_gdf.crs is None:
        shops_gdf = shops_gdf.set_crs(epsg=5181, allow_override=True)
    
    # 상점 데이터를 격자 데이터의 CRS로 변환
    shops_gdf = shops_gdf.to_crs(grid_df.crs)
    
    return grid_df, shops_gdf


# 3. 격자 중심점과 상점 위치 간의 거리 계산
def calculate_accessibility(grid_df, shops_gdf, buffer_distance):
    grid_df['accessibility'] = 0
    
    # grid_df 중심점과 shops_gdf의 좌표를 numpy 배열로 변환
    centroids = np.array([[point.x, point.y] for point in grid_df.centroid])
    shop_coords = np.array([[point.x, point.y] for point in shops_gdf.geometry])
    
    print(f"Centroids shape: {centroids.shape}")
    print(f"Shop coordinates shape: {shop_coords.shape}")
    
    # array가 비어있는지 확인
    if centroids.shape[0] == 0 or shop_coords.shape[0] == 0:
        raise ValueError("Centroid or shop coordinates array is empty")
    
    # KD-Tree를 사용하여 상점 위치에 대한 거리 계산
    tree = cKDTree(shop_coords)
    
    # 각각의 인구 밀도 중심점에 대해, 근접한 상점 개수 계산
    for centroid, index in zip(centroids, grid_df.index):
        indices = tree.query_ball_point(centroid, buffer_distance)
        grid_df.at[index, 'accessibility'] = len(indices)
    
    return grid_df

def calculate_ppr_for_shops(grid_df, shops_gdf, buffer_distance):
    shops_gdf['PPR'] = 0
    
    # grid_df 중심점과 shops_gdf의 좌표를 numpy 배열로 변환
    centroids = np.array([[point.x, point.y] for point in grid_df['centroid']])
    shop_coords = np.array([[point.x, point.y] for point in shops_gdf.geometry])
    
    # KD-Tree를 사용하여 인구 위치에 대한 거리 계산
    tree = cKDTree(centroids)
    
    # 각각의 상점 위치에 대해, 근접한 격자의 인구 밀도 합계 계산
    for shop_idx, shop in shops_gdf.iterrows():
        indices = tree.query_ball_point([shop.geometry.x, shop.geometry.y], buffer_distance)
        ppr_value = grid_df.iloc[indices]['val'].sum()
        shops_gdf.at[shop_idx, 'PPR'] = 1/ppr_value
    
    return shops_gdf

def calculate_accessibility_for_grids(grid_df, shops_gdf, buffer_distance):
    grid_df['accessibility'] = 0
    
    # grid_df 중심점과 shops_gdf의 좌표를 numpy 배열로 변환
    centroids = np.array([[point.x, point.y] for point in grid_df.centroid])
    shop_coords = np.array([[point.x, point.y] for point in shops_gdf.geometry])
    shop_ppr_values = shops_gdf['PPR'].values
    
    # KD-Tree를 사용하여 상점 위치에 대한 거리 계산
    tree = cKDTree(shop_coords)
    
    # 각각의 인구 밀도(중심점)에 대해, buffer distance 내에 있는 상점들의 PPR 합계 계산
    for grid_idx, centroid in enumerate(centroids):
        indices = tree.query_ball_point(centroid, buffer_distance)
        accessibility_value = shop_ppr_values[indices].sum()
        grid_df.at[grid_idx, 'accessibility'] = accessibility_value
    
    return grid_df

# %%
import os

current_path = os.getcwd()
data_path = os.path.join(current_path, 'data')

# 데이터 로드 및 처리 예시
grid_file = os.path.join(data_path, '(B100)국토통계_인구정보-총 인구 수(전체)-(격자) 1KM_서울특별시_202404/nlsp_020001001.shp')  # 격자 데이터 파일 경로
shops_file = os.path.join(data_path,'서울시 대규모점포 인허가 정보.shp')  # 상점 데이터 파일 경로

#  분석에 사용할 버퍼 거리 (단위: 미터)
# walk_speed = 133.1
# buffer_distance = 5 * walk_speed / 100 * 60 # 미터 단위
buffer_distance = 1000

# 격자 및 상점 데이터 불러오기
grid_df = gpd.read_file(grid_file)
shops_gdf = gpd.read_file(shops_file, encoding='ISO-8859-1')

# 좌표계 변환
grid_df = grid_df.to_crs(epsg=5179)
shops_gdf = shops_gdf.to_crs(epsg=5179)


# column 명 변환
x_name = shops_gdf.columns[23]
y_name = shops_gdf.columns[24]
shops_gdf = shops_gdf.rename(columns={x_name: 'x', y_name: 'y'})
shops_gdf['geometry'] = shops_gdf.apply(lambda x: Point((float(x.x), float(x.y))), axis=1)

# %%
# 결측치 제거
shops_gdf = shops_gdf.dropna(subset=['x', 'y'])
grid_df = grid_df.dropna(subset=['lbl'])
grid_df = grid_df[grid_df['val'] != 0]
grid_df = grid_df[grid_df.geometry.notnull()]

grid_df.shape
# grid_df
# Out:
# (578, 4)

# %%
tqdm.pandas()

shops_gdf[['x', 'y']] = shops_gdf['geometry'].progress_apply(lambda geom: pd.Series(transform_2097_to_5179(geom.centroid.x, geom.centroid.y)))
shops_gdf['geometry'] = shops_gdf.apply(lambda x: Point((float(x.y), float(x.x))), axis=1)
# shops_gdf
# Out:
# 100%|██████████| 922/922 [00:08<00:00, 113.75it/s]

# %%
# 격자 중심점 계산
grid_df = calculate_centroids(grid_df)

# %%
# 접근성 분석
grid_df = calculate_accessibility(grid_df, shops_gdf, buffer_distance)

# 결과 출력
print(grid_df.head())
# Out:
# Centroids shape: (578, 2)
# Shop coordinates shape: (922, 2)
#           gid       lbl      val  \
# 0  ë¤ì¬6453   8975.00   8975.0
# 1  ë¤ì¬5651  12141.00  12141.0
# 2  ë¤ì¬6157  28042.00  28042.0
# 3  ë¤ì¬5858  22857.00  22857.0
# 4  ë¤ì¬5347  12053.00  12053.0
#
#                                             geometry                centroid  \
# 0  POLYGON ((964000 1953000, 964000 1954000, 9650...  POINT (964500 1953500)
# 1  POLYGON ((956000 1951000, 956000 1952000, 9570...  POINT (956500 1951500)
# 2  POLYGON ((961000 1957000, 961000 1958000, 9620...  POINT (961500 1957500)
# 3  POLYGON ((958000 1958000, 958000 1959000, 9590...  POINT (958500 1958500)
# 4  POLYGON ((953000 1947000, 953000 1948000, 9540...  POINT (953500 1947500)
#
#    accessibility
# 0              0
# 1             36
# 2              7
# 3              4
# 4              5

# %%
# 4. 상점별 PPR 값 계산 (2SFCA 기법 - 1단계)
shops_gdf = calculate_ppr_for_shops(grid_df, shops_gdf, buffer_distance)

print(shops_gdf['PPR'])
print(shops_gdf.shape)
# Out:
# /tmp/ipykernel_2475765/1556320008.py:100: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '3.2e-05' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   shops_gdf.at[shop_idx, 'PPR'] = 1/ppr_value
# 0       0.000032
# 1       0.000105
# 2       0.000010
# 3       0.000013
# 4       0.000017
#           ...
# 999     0.000011
# 1000    0.000026
# 1001    0.000010
# 1002    0.000012
# 1003    0.000009
# Name: PPR, Length: 922, dtype: float64
# (922, 28)

# %%
# 5. 격자별 접근성 지수 계산 (2SFCA 기법 - 2단계)
# 격자별 접근성 지수 계산
grid_df = calculate_accessibility_for_grids(grid_df, shops_gdf, buffer_distance)
# Out:
# /tmp/ipykernel_2475765/1556320008.py:119: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0.0009882039831569907' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   grid_df.at[grid_idx, 'accessibility'] = accessibility_value

# %%
for idx, row in grid_df.iterrows():
    if row['accessibility'] != 0:
        print(f"격자 {row['lbl']}의 접근성 지수: {row['accessibility']}")
# Out:
# 격자 12141.00의 접근성 지수: 0.0009882039831569907
# 격자 28042.00의 접근성 지수: 9.008501014204781e-05
# 격자 22857.00의 접근성 지수: 4.4161785932100954e-05
# 격자 12053.00의 접근성 지수: 0.00013487776194810546
# 격자 19321.00의 접근성 지수: 4.482898096140687e-05
# 격자 903.00의 접근성 지수: 0.00023432108589890172
# 격자 28864.00의 접근성 지수: 2.927283797253774e-05
# 격자 6816.00의 접근성 지수: 1.911826559094559e-05
# 격자 17218.00의 접근성 지수: 1.3097576948264571e-05
# 격자 12216.00의 접근성 지수: 7.856403409089225e-05
# 격자 9484.00의 접근성 지수: 0.0003051918397181634
# 격자 10977.00의 접근성 지수: 0.00022592977572662772
# 격자 24048.00의 접근성 지수: 5.8323463635154944e-05
# 격자 13988.00의 접근성 지수: 6.285843829446038e-05
# 격자 24014.00의 접근성 지수: 0.0001620543993950481
# 격자 35205.00의 접근성 지수: 0.00010496573549508264
# 격자 12726.00의 접근성 지수: 3.974508742433678e-05
# 격자 24287.00의 접근성 지수: 3.038622881490332e-05
# 격자 29129.00의 접근성 지수: 0.00021886337776891844
# 격자 22698.00의 접근성 지수: 7.072832587418955e-05
# 격자 14337.00의 접근성 지수: 2.9370267633324795e-05
# 격자 16077.00의 접근성 지수: 0.00010980687253298759
# 격자 16621.00의 접근성 지수: 0.0001190754029819499
# 격자 13851.00의 접근성 지수: 2.0208960653153607e-05
# 격자 29948.00의 접근성 지수: 9.46960729538546e-06
# 격자 4528.00의 접근성 지수: 8.245508833017778e-05
# 격자 27807.00의 접근성 지수: 3.4168175761096116e-05
# 격자 29628.00의 접근성 지수: 0.00012303593034270442
# 격자 25919.00의 접근성 지수: 1.6615950250601373e-05
# 격자 22162.00의 접근성 지수: 0.0002561305564886619
# 격자 42159.00의 접근성 지수: 5.4525550523062864e-05
# 격자 19329.00의 접근성 지수: 4.821214750987713e-05
# 격자 108.00의 접근성 지수: 0.00014352350197344816
# 격자 31252.00의 접근성 지수: 6.970178083801255e-05
# 격자 31241.00의 접근성 지수: 0.0006995456830326667
# 격자 21986.00의 접근성 지수: 5.470858184107655e-05
# 격자 6226.00의 접근성 지수: 0.0012574079664141253
# 격자 574.00의 접근성 지수: 4.620569337270293e-05
# 격자 7501.00의 접근성 지수: 4.1980131328328964e-05
# 격자 26457.00의 접근성 지수: 0.00042304466429053813
# 격자 34359.00의 접근성 지수: 7.504288558423818e-05
# 격자 13661.00의 접근성 지수: 0.0001246805062028552
# 격자 852.00의 접근성 지수: 8.351634490338384e-05
# 격자 6572.00의 접근성 지수: 0.0001915267937370527
# 격자 310.00의 접근성 지수: 4.5641050802841154e-05
# 격자 3643.00의 접근성 지수: 0.0003816716662524275
# 격자 16059.00의 접근성 지수: 3.207430503168881e-05
# 격자 30967.00의 접근성 지수: 7.200288011520461e-05
# 격자 7827.00의 접근성 지수: 7.622117074313297e-05
# 격자 10648.00의 접근성 지수: 0.00014776957483842473
# 격자 25458.00의 접근성 지수: 2.2775411665565854e-05
# 격자 7448.00의 접근성 지수: 0.0003904691953243504
# 격자 1320.00의 접근성 지수: 0.00010067406612438391
# 격자 3234.00의 접근성 지수: 6.285843829446038e-05
# 격자 23421.00의 접근성 지수: 7.182672269877525e-05
# 격자 4082.00의 접근성 지수: 0.00016189330845241346
# 격자 24814.00의 접근성 지수: 0.00010301112514805053
# 격자 2865.00의 접근성 지수: 3.657934756551201e-05
# 격자 22402.00의 접근성 지수: 0.00016089345484156657
# 격자 22178.00의 접근성 지수: 8.270698666746536e-05
# 격자 978.00의 접근성 지수: 0.00013588748038744156
# 격자 39500.00의 접근성 지수: 2.052104522761235e-05
# 격자 31656.00의 접근성 지수: 1.1644832605531296e-05
# 격자 15763.00의 접근성 지수: 0.00010644950048998422
# 격자 31251.00의 접근성 지수: 7.503043930892298e-05
# 격자 21551.00의 접근성 지수: 6.883711122042002e-05
# 격자 20594.00의 접근성 지수: 0.00010603849656818198
# 격자 30911.00의 접근성 지수: 5.764895575251798e-05
# 격자 36928.00의 접근성 지수: 7.859042405264641e-05
# 격자 24175.00의 접근성 지수: 2.3380327792195646e-05
# 격자 2058.00의 접근성 지수: 0.00013807351548842232
# 격자 23916.00의 접근성 지수: 3.1293485386655524e-05
# 격자 33151.00의 접근성 지수: 6.678324052677629e-05
# 격자 1181.00의 접근성 지수: 1.911826559094559e-05
# 격자 36617.00의 접근성 지수: 0.00016335053337797616
# 격자 28799.00의 접근성 지수: 0.0013081870567241774
# 격자 19472.00의 접근성 지수: 0.0003908935655480879
# 격자 325.00의 접근성 지수: 0.00011062788588284822
# 격자 8658.00의 접근성 지수: 7.085005875859451e-05
# 격자 3399.00의 접근성 지수: 1.1644832605531296e-05
# 격자 29225.00의 접근성 지수: 6.733786793565459e-05
# 격자 3451.00의 접근성 지수: 0.00016648463471088696
# 격자 31993.00의 접근성 지수: 0.0001450747134774409
# 격자 15135.00의 접근성 지수: 0.0001536920751013206
# 격자 14012.00의 접근성 지수: 4.721349401003385e-05
# 격자 81.00의 접근성 지수: 8.168091562380473e-05
# 격자 5416.00의 접근성 지수: 4.248747450215055e-05
# 격자 13795.00의 접근성 지수: 0.000209885612341274
# 격자 233.00의 접근성 지수: 9.179004979613836e-05
# 격자 4760.00의 접근성 지수: 9.869322329493494e-05
# 격자 9856.00의 접근성 지수: 0.00013267219634180958
# 격자 9007.00의 접근성 지수: 0.00010190889496781018
# 격자 22363.00의 접근성 지수: 2.5211778943122226e-05
# 격자 2035.00의 접근성 지수: 0.00034264949977734645
# 격자 23570.00의 접근성 지수: 3.711149892378146e-05
# 격자 38995.00의 접근성 지수: 0.00013174035509973432
# 격자 14740.00의 접근성 지수: 7.567273098583536e-05
# 격자 25382.00의 접근성 지수: 0.000167907095311293
# 격자 3630.00의 접근성 지수: 0.001062089740021591
# 격자 365.00의 접근성 지수: 2.9559315269677673e-05
# 격자 26313.00의 접근성 지수: 5.220393451865641e-05
# 격자 15697.00의 접근성 지수: 0.00020803032477785137
# 격자 20114.00의 접근성 지수: 7.167831348900156e-05
# 격자 39466.00의 접근성 지수: 9.499897648025011e-05
# 격자 23037.00의 접근성 지수: 0.00020020019667140826
# 격자 26238.00의 접근성 지수: 6.868924482732879e-05
# 격자 25620.00의 접근성 지수: 0.00017972619560590317
# 격자 16.00의 접근성 지수: 2.4689697212003477e-05
# 격자 41738.00의 접근성 지수: 2.5253162958660573e-05
# 격자 5026.00의 접근성 지수: 2.5593775593775595e-05
# 격자 23190.00의 접근성 지수: 0.0002868078808974623
# 격자 22632.00의 접근성 지수: 6.759707141813963e-05
# 격자 585.00의 접근성 지수: 0.00013040024312277254
# 격자 22971.00의 접근성 지수: 3.447920854048231e-05
# 격자 2760.00의 접근성 지수: 0.0001860207387958564
# 격자 9500.00의 접근성 지수: 3.7144510208038546e-05
# 격자 28.00의 접근성 지수: 0.00019760471407581298
# 격자 7098.00의 접근성 지수: 5.014627447645727e-05
# 격자 14430.00의 접근성 지수: 2.255299954894001e-05
# 격자 7819.00의 접근성 지수: 1.2145503127467055e-05
# 격자 28703.00의 접근성 지수: 5.324596185003183e-05
# 격자 21329.00의 접근성 지수: 8.739027480866358e-05
# 격자 3892.00의 접근성 지수: 0.00011186794649963406
# 격자 12044.00의 접근성 지수: 8.11270864135643e-05
# 격자 3832.00의 접근성 지수: 3.9833924803698366e-05
# 격자 7563.00의 접근성 지수: 3.3847237513703966e-05
# 격자 1136.00의 접근성 지수: 7.285727353456178e-05
# 격자 14076.00의 접근성 지수: 1.7639173075566216e-05
# 격자 35665.00의 접근성 지수: 3.77274611159782e-05
# 격자 32127.00의 접근성 지수: 3.908319601284234e-05
# 격자 8.00의 접근성 지수: 0.0005417743223337042
# 격자 32096.00의 접근성 지수: 4.612610873946512e-05
# 격자 29645.00의 접근성 지수: 0.00014001798729721359
# 격자 920.00의 접근성 지수: 0.00010207441885399347
# 격자 19148.00의 접근성 지수: 0.00017944542912867213
# 격자 20.00의 접근성 지수: 4.1204224181231115e-05
# 격자 36882.00의 접근성 지수: 2.0383619723190443e-05
# 격자 2914.00의 접근성 지수: 6.244980312985366e-05
# 격자 36243.00의 접근성 지수: 1.71933564870534e-05
# 격자 16277.00의 접근성 지수: 2.7490773959100228e-05
# 격자 23236.00의 접근성 지수: 4.68362137604796e-05
# 격자 24491.00의 접근성 지수: 6.972855630297308e-05
# 격자 12320.00의 접근성 지수: 6.405080302394223e-05
# 격자 29129.00의 접근성 지수: 1.2019375232875395e-05
# 격자 484.00의 접근성 지수: 9.811646955791174e-05
# 격자 1572.00의 접근성 지수: 0.00018065061167033713
# 격자 6268.00의 접근성 지수: 9.083477155054955e-06
# 격자 13205.00의 접근성 지수: 0.00019316574409510045
# 격자 11544.00의 접근성 지수: 0.00010730278136620114
# 격자 5830.00의 접근성 지수: 2.127297481279782e-05
# 격자 37020.00의 접근성 지수: 2.7652057634556635e-05
# 격자 23432.00의 접근성 지수: 0.00015299913465939742
# 격자 1866.00의 접근성 지수: 1.1911710402496694e-05
# 격자 7991.00의 접근성 지수: 9.166274758175837e-05
# 격자 30079.00의 접근성 지수: 2.2021096210169343e-05
# 격자 16702.00의 접근성 지수: 1.2594458438287154e-05
# 격자 40590.00의 접근성 지수: 0.00011656086682958437
# 격자 34420.00의 접근성 지수: 8.958165367732689e-05
# 격자 454.00의 접근성 지수: 9.166303140916862e-05
# 격자 13985.00의 접근성 지수: 7.62504488371623e-05
# 격자 5825.00의 접근성 지수: 0.00014977053978928122
# 격자 31215.00의 접근성 지수: 6.369541665883831e-05
# 격자 9302.00의 접근성 지수: 6.519517939459571e-05
# 격자 3177.00의 접근성 지수: 6.911907023604138e-05
# 격자 30631.00의 접근성 지수: 6.21976276496262e-05
# 격자 289.00의 접근성 지수: 8.921428837025438e-05
# 격자 17935.00의 접근성 지수: 0.0001986040982168014
# 격자 18070.00의 접근성 지수: 4.801869288362698e-05
# 격자 5507.00의 접근성 지수: 0.0001425310627120275
# 격자 21850.00의 접근성 지수: 6.944335234032917e-05
# 격자 1171.00의 접근성 지수: 3.2651677027209587e-05
# 격자 22443.00의 접근성 지수: 4.178505766337958e-05
# 격자 16029.00의 접근성 지수: 6.926469809127961e-05
# 격자 13191.00의 접근성 지수: 4.538141284486935e-05
# 격자 102.00의 접근성 지수: 1.8871841325558133e-05
# 격자 37578.00의 접근성 지수: 7.8729807546665e-05
# 격자 12073.00의 접근성 지수: 8.144482841193794e-05
# 격자 8948.00의 접근성 지수: 0.0002794947344089977
# 격자 14555.00의 접근성 지수: 0.00020074635867117056
# 격자 13760.00의 접근성 지수: 0.00013668318331999213
# 격자 26123.00의 접근성 지수: 8.960815768513566e-05
# 격자 14717.00의 접근성 지수: 0.0005746276990076318
# 격자 139.00의 접근성 지수: 5.173382699407453e-05
# 격자 1258.00의 접근성 지수: 7.768485795081568e-05
# 격자 10405.00의 접근성 지수: 0.0001237753082359236
# 격자 5044.00의 접근성 지수: 2.5017803975086065e-05
# 격자 21841.00의 접근성 지수: 0.00023530144404514106
# 격자 26044.00의 접근성 지수: 5.2466865002233445e-05
# 격자 12037.00의 접근성 지수: 0.0001565709600193759
# 격자 29374.00의 접근성 지수: 0.0001205073995826132
# 격자 12701.00의 접근성 지수: 1.166942843139543e-05
# 격자 8487.00의 접근성 지수: 3.127443315089914e-05
# 격자 16110.00의 접근성 지수: 0.00012306855748966437
# 격자 258.00의 접근성 지수: 1.6514185685503846e-05
# 격자 2090.00의 접근성 지수: 4.5125155753994926e-05
# 격자 32950.00의 접근성 지수: 8.673710303558944e-05
# 격자 13298.00의 접근성 지수: 4.716438623997319e-05
# 격자 25918.00의 접근성 지수: 3.088967915542824e-05
# 격자 32375.00의 접근성 지수: 9.706669918584986e-05
# 격자 3105.00의 접근성 지수: 6.310209919649994e-05
# 격자 11173.00의 접근성 지수: 0.0001119656489903096
# 격자 22013.00의 접근성 지수: 2.628141374182427e-05
# 격자 12207.00의 접근성 지수: 4.79111415185069e-05
# 격자 3771.00의 접근성 지수: 3.012229652388698e-05
# 격자 14678.00의 접근성 지수: 8.921081391357341e-05
# 격자 9038.00의 접근성 지수: 0.0001142742151810033
# 격자 25473.00의 접근성 지수: 6.19079942408226e-05
# 격자 28757.00의 접근성 지수: 1.3555462173482805e-05
# 격자 28733.00의 접근성 지수: 4.8669239752752805e-05
# 격자 10952.00의 접근성 지수: 6.97926554267088e-05
# 격자 3400.00의 접근성 지수: 5.173382699407453e-05
# 격자 6072.00의 접근성 지수: 8.873708497052771e-05
# 격자 25922.00의 접근성 지수: 6.870540538026028e-05
# 격자 32903.00의 접근성 지수: 0.00013043738785882027
# 격자 21590.00의 접근성 지수: 2.776578960801192e-05
# 격자 21155.00의 접근성 지수: 3.667691442046853e-05
# 격자 6078.00의 접근성 지수: 4.1869399897926597e-05
# 격자 7462.00의 접근성 지수: 0.00011935319249088252
# 격자 23162.00의 접근성 지수: 0.00016930882203871318
# 격자 27156.00의 접근성 지수: 7.269287516322261e-05
# 격자 16.00의 접근성 지수: 5.769049022483616e-05
# 격자 4384.00의 접근성 지수: 5.4300006413127325e-05
# 격자 1411.00의 접근성 지수: 7.573294745600189e-05
# 격자 12736.00의 접근성 지수: 0.00011506270520012334
# 격자 25903.00의 접근성 지수: 7.876872534830921e-05
# 격자 2695.00의 접근성 지수: 0.0002505108512505368
# 격자 736.00의 접근성 지수: 0.0015172242847893763
# 격자 19.00의 접근성 지수: 2.197615462644062e-05
# 격자 23718.00의 접근성 지수: 2.102695655830775e-05
# 격자 29060.00의 접근성 지수: 3.452329170478379e-05
# 격자 10646.00의 접근성 지수: 6.727012022316124e-05
# 격자 6379.00의 접근성 지수: 0.00021306671877305554
# 격자 31991.00의 접근성 지수: 0.00014136688497926457
# 격자 60.00의 접근성 지수: 6.931019436762468e-05
# 격자 5199.00의 접근성 지수: 4.68362137604796e-05
# 격자 29763.00의 접근성 지수: 0.00010098861472069171
# 격자 15140.00의 접근성 지수: 2.345765892563922e-05
# 격자 4724.00의 접근성 지수: 7.574656434651259e-05
# 격자 36721.00의 접근성 지수: 0.00011104893721939886
# 격자 4309.00의 접근성 지수: 0.00017600153309367186
# 격자 9629.00의 접근성 지수: 8.983237185826371e-05
# 격자 20035.00의 접근성 지수: 0.00012618032988541997
# 격자 25052.00의 접근성 지수: 3.445328456981479e-05
# 격자 11.00의 접근성 지수: 6.628884506383874e-05
# 격자 8009.00의 접근성 지수: 3.8282640736558005e-05
# 격자 25966.00의 접근성 지수: 0.00012849308443036204
# 격자 17255.00의 접근성 지수: 9.559652613665013e-05
# 격자 25665.00의 접근성 지수: 5.7429281297084945e-05
# 격자 215.00의 접근성 지수: 6.33221257162754e-05
# 격자 18941.00의 접근성 지수: 0.00017917050236158655
# 격자 292.00의 접근성 지수: 8.824261330744826e-05
# 격자 26577.00의 접근성 지수: 3.9325065215576585e-05
# 격자 36709.00의 접근성 지수: 0.0001280104321157566
# 격자 3645.00의 접근성 지수: 6.546005340921517e-05
# 격자 30825.00의 접근성 지수: 0.00010026602679358479
# 격자 437.00의 접근성 지수: 3.0678400966078374e-05
# 격자 21364.00의 접근성 지수: 1.6830766641420516e-05
# 격자 5820.00의 접근성 지수: 3.127443315089914e-05
# 격자 34816.00의 접근성 지수: 2.288172436674828e-05
# 격자 3386.00의 접근성 지수: 7.880296395010974e-05
# 격자 3301.00의 접근성 지수: 7.335595056737868e-05
# 격자 27581.00의 접근성 지수: 0.0002509931966055354
# 격자 22612.00의 접근성 지수: 0.00020264009050195532
# 격자 20669.00의 접근성 지수: 4.2073344298862466e-05
# 격자 4909.00의 접근성 지수: 2.8364563348285513e-05
# 격자 10959.00의 접근성 지수: 3.840169021246696e-05
# 격자 36590.00의 접근성 지수: 0.00023028827893492826
# 격자 17301.00의 접근성 지수: 7.808821093670571e-05
# 격자 26679.00의 접근성 지수: 0.00013117153538845053
# 격자 16000.00의 접근성 지수: 1.768284057150941e-05
# 격자 29054.00의 접근성 지수: 3.427394451512776e-05
# 격자 25924.00의 접근성 지수: 0.00022360634443195887
# 격자 24707.00의 접근성 지수: 8.060447084529109e-05
# 격자 39202.00의 접근성 지수: 0.00010042291210365146
# 격자 27561.00의 접근성 지수: 9.998346472165333e-05
# 격자 17597.00의 접근성 지수: 2.829913180689224e-05
# 격자 1851.00의 접근성 지수: 8.07275615237228e-05
# 격자 6729.00의 접근성 지수: 4.551732338178182e-05
# 격자 14903.00의 접근성 지수: 0.0005042385505276328
# 격자 13628.00의 접근성 지수: 0.0001948626530414797
# 격자 120.00의 접근성 지수: 3.738437084725948e-05
# 격자 20231.00의 접근성 지수: 8.398163759054309e-05
# 격자 16291.00의 접근성 지수: 7.515135215655527e-05
# 격자 22957.00의 접근성 지수: 7.516780581381301e-05
# 격자 19204.00의 접근성 지수: 5.620875845905393e-05
# 격자 3646.00의 접근성 지수: 7.416073603304385e-05
# 격자 26040.00의 접근성 지수: 3.549188961669467e-05
# 격자 740.00의 접근성 지수: 0.0001405908464847914
# 격자 10150.00의 접근성 지수: 5.15758938770974e-05
# 격자 21426.00의 접근성 지수: 5.41213400443795e-05
# 격자 10919.00의 접근성 지수: 0.0001632481321612899
# 격자 18356.00의 접근성 지수: 5.311285487677243e-05
# 격자 20171.00의 접근성 지수: 0.00022583559168925022
# 격자 1008.00의 접근성 지수: 5.5063994656727816e-05
# 격자 13043.00의 접근성 지수: 4.359924115560205e-05
# 격자 22885.00의 접근성 지수: 6.778868706475216e-05
# 격자 3472.00의 접근성 지수: 0.0001301467656006035
# 격자 16612.00의 접근성 지수: 0.00010718150788304178
# 격자 27326.00의 접근성 지수: 8.79870486364312e-05
# 격자 252.00의 접근성 지수: 2.2076517208645165e-05
# 격자 34227.00의 접근성 지수: 9.926928587510853e-05
# 격자 10711.00의 접근성 지수: 0.000382920759294958
# 격자 1869.00의 접근성 지수: 2.9642245862199596e-05
# 격자 11.00의 접근성 지수: 6.90699686498738e-05
# 격자 9679.00의 접근성 지수: 4.642653215408115e-05
# 격자 27671.00의 접근성 지수: 0.00015060580155166632
# 격자 1174.00의 접근성 지수: 0.00013360127040207867
# 격자 12886.00의 접근성 지수: 0.00010284973587738135
# 격자 2166.00의 접근성 지수: 7.414608092725667e-05
# 격자 5405.00의 접근성 지수: 3.157423248446203e-05
# 격자 26898.00의 접근성 지수: 9.318098497803292e-05
# 격자 22690.00의 접근성 지수: 7.828152619063747e-05
# 격자 37018.00의 접근성 지수: 0.00018662428940778244
# 격자 7042.00의 접근성 지수: 6.369541665883831e-05
# 격자 44869.00의 접근성 지수: 0.00014289894345859388
# 격자 27444.00의 접근성 지수: 6.671456663195297e-05
# 격자 6555.00의 접근성 지수: 0.00017974091810225826
# 격자 8452.00의 접근성 지수: 0.00015296367112810707
# 격자 39536.00의 접근성 지수: 4.9511871631479213e-05
# 격자 28853.00의 접근성 지수: 8.532740153623867e-05
# 격자 18307.00의 접근성 지수: 2.1512315800795955e-05
# 격자 7204.00의 접근성 지수: 0.00025697876936672126
# 격자 16753.00의 접근성 지수: 6.768288703187497e-05
# 격자 10659.00의 접근성 지수: 0.00011725835772651987
# 격자 29285.00의 접근성 지수: 0.00023028827893492826
# 격자 21231.00의 접근성 지수: 0.0002315747686364171
# 격자 20953.00의 접근성 지수: 3.212128048286869e-05
# 격자 352.00의 접근성 지수: 8.401625223034547e-05
# 격자 29202.00의 접근성 지수: 5.307306962430832e-05
# 격자 1531.00의 접근성 지수: 4.363115722214995e-05
# 격자 22874.00의 접근성 지수: 9.479750571835349e-05
# 격자 36073.00의 접근성 지수: 8.898772849987e-05
# 격자 1181.00의 접근성 지수: 1.979149103264094e-05
# 격자 31624.00의 접근성 지수: 0.0002819344849802132
# 격자 95.00의 접근성 지수: 0.00022204875379434733
# 격자 4230.00의 접근성 지수: 4.325725874182664e-05
# 격자 1777.00의 접근성 지수: 2.3482446870963955e-05
# 격자 23594.00의 접근성 지수: 5.178614041636518e-05
# 격자 12810.00의 접근성 지수: 7.823584382712178e-05
# 격자 17006.00의 접근성 지수: 0.0005382556767657079
# 격자 23467.00의 접근성 지수: 0.00010936652363998342
# 격자 49.00의 접근성 지수: 3.277775046298573e-05
# 격자 25593.00의 접근성 지수: 6.525154504080232e-05
# 격자 28317.00의 접근성 지수: 5.039465020110625e-05
# 격자 32232.00의 접근성 지수: 0.00018078866559301135
# 격자 34020.00의 접근성 지수: 0.00010927186905451683
# 격자 20065.00의 접근성 지수: 1.3555462173482805e-05
# 격자 3556.00의 접근성 지수: 2.1512315800795955e-05
# 격자 1608.00의 접근성 지수: 0.00015134698819493494
# 격자 21595.00의 접근성 지수: 0.00011217969412070517
# 격자 8920.00의 접근성 지수: 3.876462112014655e-05
# 격자 7703.00의 접근성 지수: 3.8988529199873884e-05
# 격자 14970.00의 접근성 지수: 2.3718055910631314e-05
# 격자 23189.00의 접근성 지수: 0.00010471589131003004
# 격자 7877.00의 접근성 지수: 0.00019811830570024385
# 격자 2539.00의 접근성 지수: 0.00022050830249323316
# 격자 25852.00의 접근성 지수: 2.6793489182128743e-05
# 격자 15419.00의 접근성 지수: 0.00019006224567595743
# 격자 1033.00의 접근성 지수: 2.7239466365411212e-05
# 격자 31853.00의 접근성 지수: 9.916466125188722e-05
# 격자 24225.00의 접근성 지수: 6.172066977181175e-05
# 격자 39839.00의 접근성 지수: 0.0003197251081019794
# 격자 9760.00의 접근성 지수: 0.0003783169298965767
# 격자 7653.00의 접근성 지수: 4.199464534835003e-05
# 격자 3929.00의 접근성 지수: 4.8004683659441555e-05
# 격자 4524.00의 접근성 지수: 0.00012524880428275506
# 격자 18827.00의 접근성 지수: 2.0208960653153607e-05
# 격자 45.00의 접근성 지수: 5.8532615098418456e-05
# 격자 11074.00의 접근성 지수: 8.134446191494051e-05
# 격자 13049.00의 접근성 지수: 0.00010025178515572952
# 격자 2535.00의 접근성 지수: 0.00011165611178978299
# 격자 27993.00의 접근성 지수: 0.00029273232851032455
# 격자 24132.00의 접근성 지수: 7.099615894605353e-05
# 격자 23756.00의 접근성 지수: 0.00016195140331458742
# 격자 15363.00의 접근성 지수: 0.00027151846013990046
# 격자 18623.00의 접근성 지수: 0.00014975411935990758
# 격자 10791.00의 접근성 지수: 2.7479178241861028e-05
# 격자 21332.00의 접근성 지수: 0.00013610997686130393
# 격자 5747.00의 접근성 지수: 0.00015727941615311668
# 격자 39029.00의 접근성 지수: 0.00011692602827618952
# 격자 19254.00의 접근성 지수: 0.00010851218123721865
# 격자 36648.00의 접근성 지수: 8.198722557991625e-05
# 격자 4128.00의 접근성 지수: 4.712933022363282e-05
# 격자 15928.00의 접근성 지수: 3.3378351503624985e-05
# 격자 39252.00의 접근성 지수: 8.145437376290594e-05
# 격자 32739.00의 접근성 지수: 1.8871841325558133e-05
# 격자 258.00의 접근성 지수: 0.00011010038688419804
# 격자 16259.00의 접근성 지수: 3.3051081552379554e-05
# 격자 17473.00의 접근성 지수: 0.00011461646962476462
# 격자 11011.00의 접근성 지수: 0.00010529242557097497
# 격자 31262.00의 접근성 지수: 0.00014778223416868905
# 격자 6478.00의 접근성 지수: 5.4327500743508124e-05
# 격자 5134.00의 접근성 지수: 7.846820880894729e-05
# 격자 449.00의 접근성 지수: 0.0001643447806763499
# 격자 30624.00의 접근성 지수: 0.00045661865777889797
# 격자 28692.00의 접근성 지수: 8.50507705890643e-05
# 격자 25820.00의 접근성 지수: 9.880120020841525e-05
# 격자 11968.00의 접근성 지수: 9.756682953783444e-05
# 격자 32233.00의 접근성 지수: 0.00010209480856377984
# 격자 27375.00의 접근성 지수: 6.127417584572681e-05
# 격자 10428.00의 접근성 지수: 2.0208960653153607e-05
# 격자 9470.00의 접근성 지수: 0.0001176650958014746
# 격자 36651.00의 접근성 지수: 3.8265423543314394e-05
# 격자 15303.00의 접근성 지수: 0.00028082002547285233
# 격자 8505.00의 접근성 지수: 9.528568425191697e-05
# 격자 2115.00의 접근성 지수: 0.00010676725679380454
# 격자 35708.00의 접근성 지수: 0.0002054683282393144
# 격자 599.00의 접근성 지수: 0.0001861045007687906
# 격자 36447.00의 접근성 지수: 0.00010109700926345407
# 격자 24151.00의 접근성 지수: 7.276243152626324e-05
# 격자 1275.00의 접근성 지수: 0.0001762326389739476
# 격자 21653.00의 접근성 지수: 4.531188553547275e-05
# 격자 8919.00의 접근성 지수: 9.198934126576232e-05
# 격자 20949.00의 접근성 지수: 0.00024414118202082546
# 격자 3578.00의 접근성 지수: 0.00017924206934321084
# 격자 21924.00의 접근성 지수: 7.387142314364663e-05
# 격자 300.00의 접근성 지수: 3.474429913571166e-05
# 격자 24934.00의 접근성 지수: 0.00017476111527548632
# 격자 20027.00의 접근성 지수: 2.924489676551442e-05
# 격자 10362.00의 접근성 지수: 0.00020921513117454232
# 격자 29009.00의 접근성 지수: 6.295493619770864e-05
# 격자 14881.00의 접근성 지수: 0.00020638194026790854
# 격자 7482.00의 접근성 지수: 0.00013382620450381783
# 격자 31695.00의 접근성 지수: 9.17879376237079e-05
# 격자 nan의 접근성 지수: 7.736559321619995e-05
# 격자 nan의 접근성 지수: 0.000294940943228294
# 격자 nan의 접근성 지수: 3.163856107824216e-05
# 격자 nan의 접근성 지수: 0.00024626529718123986
# 격자 nan의 접근성 지수: 0.0001570589293277179
# 격자 nan의 접근성 지수: 8.575142212273581e-05
# 격자 nan의 접근성 지수: 0.00010657004427209262
# 격자 nan의 접근성 지수: 0.0001647117357180456
# 격자 nan의 접근성 지수: 1.2594458438287154e-05
# 격자 nan의 접근성 지수: 4.759638267491671e-05
# 격자 nan의 접근성 지수: 0.00015156428937842414
# 격자 nan의 접근성 지수: 0.00013008558611584333
# 격자 nan의 접근성 지수: 0.0014835048637136937
# 격자 nan의 접근성 지수: 9.587272934912209e-05
# 격자 nan의 접근성 지수: 4.178505766337958e-05
# 격자 nan의 접근성 지수: 0.00019642784334361466
# 격자 nan의 접근성 지수: 1.7713536684734473e-05
# 격자 nan의 접근성 지수: 5.850952318641842e-05
# 격자 nan의 접근성 지수: 0.00012899446175111307
# 격자 nan의 접근성 지수: 0.00017204592838230453

# %%
grid_df.dropna(subset=['geometry'], inplace=True)
grid_df.shape
# Out:
# (578, 6)

# %% [markdown]
# ### 서울시 동 경계 데이터

# %%
geojson_file = 'EMD_Seoul.geojson'
gdf = gpd.read_file(geojson_file)
gdf.head()
# Out:
#   BASE_DATE ADM_DR_CD ADM_DR_NM OBJECTID  \
# 0  20200630   1101053       사직동        1
# 1  20200630   1101054       삼청동        2
# 2  20200630   1101055       부암동        3
# 3  20200630   1101056       평창동        4
# 4  20200630   1101057       무악동        5
#
#                                             geometry
# 0  MULTIPOLYGON (((126.97399 37.57823, 126.974 37...
# 1  MULTIPOLYGON (((126.97714 37.59768, 126.9773 3...
# 2  MULTIPOLYGON (((126.96173 37.60714, 126.96182 ...
# 3  MULTIPOLYGON (((126.97509 37.63118, 126.97488 ...
# 4  MULTIPOLYGON (((126.95975 37.58001, 126.96006 ...

# %%
# 좌표계 변환 
grid_df, gdf = align_crs(grid_df, gdf)

# %%
# 포인트가 속한 행정동 경계 찾기
def find_admin_dong(point, gdf):
    for idx, row in gdf.iterrows():
        if row['geometry'].contains(point):  # point가 폴리곤 내부에 있는지 확인
            return row['ADM_DR_NM']  # 행정동 이름 반환
    return None  # 행정동 경계에 포함되지 않으면 None을 반환

grid_df['District_Name'] = grid_df.apply(lambda row: find_admin_dong(row['centroid'], gdf), axis=1)

print(grid_df['District_Name'].head(10))
# Out:
# 0    면목7동
# 1     장충동
# 2    월계1동
# 3     송중동
# 4    한강로동
# 5    월곡2동
# 6     옥수동
# 7     강일동
# 8     창5동
# 9     광장동
# Name: District_Name, dtype: object

# %%
grid_df.head(15)
# Out:
#            gid       lbl      val  \
# 0   ë¤ì¬6453   8975.00   8975.0
# 1   ë¤ì¬5651  12141.00  12141.0
# 2   ë¤ì¬6157  28042.00  28042.0
# 3   ë¤ì¬5858  22857.00  22857.0
# 4   ë¤ì¬5347  12053.00  12053.0
# 5   ë¤ì¬5955  19321.00  19321.0
# 6   ë¤ì¬5748    903.00    903.0
# 7   ë¤ì¬7152  15448.00  15448.0
# 8   ë¤ì¬5961  28864.00  28864.0
# 9   ë¤ì¬6549   6816.00   6816.0
# 10  ë¤ì¬6163  17218.00  17218.0
# 11  ë¤ì¬4051  12216.00  12216.0
# 12  ë¤ì¬5747   9484.00   9484.0
# 13  ë¤ì¬5947  10977.00  10977.0
# 14  ë¤ì¬5662   4682.00   4682.0
#
#                                              geometry                centroid  \
# 0   POLYGON ((964000 1953000, 964000 1954000, 9650...  POINT (964500 1953500)
# 1   POLYGON ((956000 1951000, 956000 1952000, 9570...  POINT (956500 1951500)
# 2   POLYGON ((961000 1957000, 961000 1958000, 9620...  POINT (961500 1957500)
# 3   POLYGON ((958000 1958000, 958000 1959000, 9590...  POINT (958500 1958500)
# 4   POLYGON ((953000 1947000, 953000 1948000, 9540...  POINT (953500 1947500)
# 5   POLYGON ((959000 1955000, 959000 1956000, 9600...  POINT (959500 1955500)
# 6   POLYGON ((957000 1948000, 957000 1949000, 9580...  POINT (957500 1948500)
# 7   POLYGON ((971000 1952000, 971000 1953000, 9720...  POINT (971500 1952500)
# 8   POLYGON ((959000 1961000, 959000 1962000, 9600...  POINT (959500 1961500)
# 9   POLYGON ((965000 1949000, 965000 1950000, 9660...  POINT (965500 1949500)
# 10  POLYGON ((961000 1963000, 961000 1964000, 9620...  POINT (961500 1963500)
# 11  POLYGON ((940000 1951000, 940000 1952000, 9410...  POINT (940500 1951500)
# 12  POLYGON ((957000 1947000, 957000 1948000, 9580...  POINT (957500 1947500)
# 13  POLYGON ((959000 1947000, 959000 1948000, 9600...  POINT (959500 1947500)
# 14  POLYGON ((956000 1962000, 956000 1963000, 9570...  POINT (956500 1962500)
#
#     accessibility District_Name
# 0        0.000000          면목7동
# 1        0.000988           장충동
# 2        0.000090          월계1동
# 3        0.000044           송중동
# 4        0.000135          한강로동
# 5        0.000045          월곡2동
# 6        0.000234           옥수동
# 7        0.000000           강일동
# 8        0.000029           창5동
# 9        0.000019           광장동
# 10       0.000013          상계9동
# 11       0.000079          가양1동
# 12       0.000305           신사동
# 13       0.000226           청담동
# 14       0.000000           우이동

# %% [markdown]
# * 행정 구역 내에 속하지 않는 경계 지역 (29개)는 분석에서 제외.

# %%
for idx, row in grid_df.iterrows():
    if pd.isna(row['District_Name']):
        print(f"Missing geometry is {row['centroid']}")
        print(f"Missing district name for grid {idx}")
# Out:
# Missing geometry is POINT (950500 1962500)
# Missing district name for grid 50
# Missing geometry is POINT (966500 1940500)
# Missing district name for grid 54
# Missing geometry is POINT (968500 1941500)
# Missing district name for grid 101
# Missing geometry is POINT (960500 1965500)
# Missing district name for grid 119
# Missing geometry is POINT (944500 1942500)
# Missing district name for grid 120
# Missing geometry is POINT (971500 1949500)
# Missing district name for grid 146
# Missing geometry is POINT (942500 1942500)
# Missing district name for grid 162
# Missing geometry is POINT (939500 1941500)
# Missing district name for grid 175
# Missing geometry is POINT (947500 1958500)
# Missing district name for grid 191
# Missing geometry is POINT (939500 1942500)
# Missing district name for grid 269
# Missing geometry is POINT (949500 1961500)
# Missing district name for grid 277
# Missing geometry is POINT (956500 1939500)
# Missing district name for grid 300
# Missing geometry is POINT (959500 1966500)
# Missing district name for grid 309
# Missing geometry is POINT (951500 1962500)
# Missing district name for grid 314
# Missing geometry is POINT (944500 1943500)
# Missing district name for grid 327
# Missing geometry is POINT (965500 1960500)
# Missing district name for grid 390
# Missing geometry is POINT (939500 1944500)
# Missing district name for grid 404
# Missing geometry is POINT (943500 1943500)
# Missing district name for grid 406
# Missing geometry is POINT (969500 1942500)
# Missing district name for grid 444
# Missing geometry is POINT (945500 1939500)
# Missing district name for grid 457
# Missing geometry is POINT (958500 1940500)
# Missing district name for grid 462
# Missing geometry is POINT (957500 1939500)
# Missing district name for grid 472
# Missing geometry is POINT (946500 1938500)
# Missing district name for grid 476
# Missing geometry is POINT (939500 1943500)
# Missing district name for grid 481
# Missing geometry is POINT (968500 1945500)
# Missing district name for grid 484
# Missing geometry is POINT (945500 1940500)
# Missing district name for grid 495
# Missing geometry is POINT (970500 1953500)
# Missing district name for grid 548
# Missing geometry is POINT (935500 1951500)
# Missing district name for grid 588
# Missing geometry is POINT (966500 1956500)
# Missing district name for grid 592

# %%
pd.isna(grid_df['District_Name']).sum()
# Out:
# 29

# %%
grid_df = grid_df.dropna(subset=['District_Name'])
grid_df.shape
# Out:
# (549, 7)

# %% [markdown]
# ### 서울 상권분석 (소비 매출) 데이터

# %%
sales_path = os.path.join(data_path, '서울시 상권분석서비스(소득소비-행정동).csv')
sales_data = pd.read_csv(sales_path, encoding='cp949')
# sales_data['Sales'] = None

# 2024-1분기 데이터만 사용
sales_data = sales_data[sales_data['기준_년분기_코드'] == 20241]

# %%
sales_data.head(5)
# Out:
#       기준_년분기_코드    행정동_코드 행정동_코드_명  월_평균_소득_금액  소득_구간_코드     지출_총금액  \
# 1700      20241  11110680     창신2동     2112817         5  378781000
# 1701      20241  11110670     창신1동     2393308         5  885535000
# 1702      20241  11170700      보광동     2545653         6  378073000
# 1703      20241  11140650     신당5동     3027979         7  916706000
# 1704      20241  11170510      후암동     3013677         7  732920000
#
#       식료품_지출_총금액  의류_신발_지출_총금액  생활용품_지출_총금액  의료비_지출_총금액  교통_지출_총금액  교육_지출_총금액  \
# 1700   114626000       2615000      3824000    54984000    1872000    1625000
# 1701   150365000      56693000      1192000   227077000     754000   29247000
# 1702   117293000       7390000      6950000    49139000    3287000   14383000
# 1703   164793000      22144000     13424000   135532000   38454000    4674000
# 1704   308335000      12720000     10397000    36686000   11974000   30917000
#
#       유흥_지출_총금액  여가_문화_지출_총금액  기타_지출_총금액  음식_지출_총금액
# 1700    6167000       8797000    7498000  176773000
# 1701   35303000      92980000   49143000  242781000
# 1702   18357000      13263000   13958000  134053000
# 1703   55450000     107647000   17265000  357323000
# 1704    7239000      22807000   28991000  262854000

# %%
for idx, row in grid_df.iterrows():
    district_name = row['District_Name']
    if district_name in sales_data['행정동_코드_명'].values:
        grid_df.at[idx, 'Sales'] = sales_data[sales_data['행정동_코드_명']== district_name]['소득_구간_코드'].iloc[0]
    
    else:
        grid_df.at[idx, 'Sales'] = 0

# %%
grid_df['Sales'].head()
print((grid_df['Sales'] == 0).sum()) # 모든 행정 구역 동 소득 구간 정보 확인.
# Out:
# 13

# %%
grid_df
# Out:
#             gid       lbl      val  \
# 0    ë¤ì¬6453   8975.00   8975.0
# 1    ë¤ì¬5651  12141.00  12141.0
# 2    ë¤ì¬6157  28042.00  28042.0
# 3    ë¤ì¬5858  22857.00  22857.0
# 4    ë¤ì¬5347  12053.00  12053.0
# ..          ...       ...      ...
# 604  ë¤ì¬4549  12779.00  12779.0
# 605  ë¤ì¬5142  40229.00  40229.0
# 606  ë¤ì¬5548  11214.00  11214.0
# 607  ë¤ì¬5950  12661.00  12661.0
# 608  ë¤ì¬5348  13115.00  13115.0
#
#                                               geometry  \
# 0    POLYGON ((964000 1953000, 964000 1954000, 9650...
# 1    POLYGON ((956000 1951000, 956000 1952000, 9570...
# 2    POLYGON ((961000 1957000, 961000 1958000, 9620...
# 3    POLYGON ((958000 1958000, 958000 1959000, 9590...
# 4    POLYGON ((953000 1947000, 953000 1948000, 9540...
# ..                                                 ...
# 604  POLYGON ((945000 1949000, 945000 1950000, 9460...
# 605  POLYGON ((951000 1942000, 951000 1943000, 9520...
# 606  POLYGON ((955000 1948000, 955000 1949000, 9560...
# 607  POLYGON ((959000 1950000, 959000 1951000, 9600...
# 608  POLYGON ((953000 1948000, 953000 1949000, 9540...
#
#                    centroid  accessibility District_Name  Sales
# 0    POINT (964500 1953500)       0.000000          면목7동    6.0
# 1    POINT (956500 1951500)       0.000988           장충동    6.0
# 2    POINT (961500 1957500)       0.000090          월계1동    6.0
# 3    POINT (958500 1958500)       0.000044           송중동    6.0
# 4    POINT (953500 1947500)       0.000135          한강로동    9.0
# ..                      ...            ...           ...    ...
# 604  POINT (945500 1949500)       0.000000           목5동    9.0
# 605  POINT (951500 1942500)       0.000000           청룡동    6.0
# 606  POINT (955500 1948500)       0.000000         이태원1동    7.0
# 607  POINT (959500 1950500)       0.000000           사근동    7.0
# 608  POINT (953500 1948500)       0.000000          한강로동    9.0
#
# [549 rows x 8 columns]

# %% [markdown]
# * 행정 구역이 종로 1,2,3,4 동 으로 묶여 있는 곳 존재. 해당 경우, sales data 존재하지 않음.

# %%
for _, row in grid_df.iterrows():
    if row['Sales'] == 0:
        grid_df = grid_df.drop(index=_, axis=0)
        print(f"Missing sales data for {row['District_Name']}")
        
grid_df.shape
# Out:
# Missing sales data for 상계3·4동
# Missing sales data for 종로5·6가동
# Missing sales data for 종로1·2·3·4가동
# Missing sales data for 상계3·4동
# Missing sales data for 종로1·2·3·4가동
# Missing sales data for 상계6·7동
# Missing sales data for 상계3·4동
# Missing sales data for 면목3·8동
# Missing sales data for 상계3·4동
# Missing sales data for 중계2·3동
# Missing sales data for 상계3·4동
# Missing sales data for 종로1·2·3·4가동
# Missing sales data for 금호2·3가동
# (536, 8)

# %% [markdown]
# ### 서울 평균 연령 데이터

# %%
age_path = os.path.join(data_path, '평균연령_20240726021229.csv')
age_data = pd.read_csv(age_path, encoding='utf-8')
age_data.tail()
# Out:
#     동별(1) 동별(2) 동별(3) 2024 2/4 2024 2/4.1 2024 2/4.2
# 448    합계   강동구  천호2동     46.2       45.7       46.6
# 449    합계   강동구    길동     46.2       45.5       46.9
# 450    합계   강동구   강일동     43.1       41.7       44.3
# 451    합계   강동구  상일1동     40.2       39.8       40.5
# 452    합계   강동구  상일2동     40.7       39.6       41.6

# %%
for idx, row in grid_df.iterrows():
    district_name = row['District_Name']
    if district_name in age_data['동별(3)'].values:
        grid_df.at[idx, 'Average_age'] = age_data[age_data['동별(3)']== district_name]['2024 2/4'].iloc[0]
    
    else:
        grid_df.at[idx, 'Average_age'] = 0

# %%
grid_df['Average_age'].head()
print((grid_df['Average_age'] == 0).sum()) # 모든 행정 구역 동 평균 연령 정보 확인.
# Out:
# 3

# %%
for _, row in grid_df.iterrows():
    if row['Average_age'] == 0:
        grid_df = grid_df.drop(index=_, axis=0)
        print(f"Missing Average_age data for {row['District_Name']}")
        
grid_df.shape
# Out:
# Missing Average_age data for 상일동
# Missing Average_age data for 상일동
# Missing Average_age data for 일원2동
# (533, 9)

# %% [markdown]
# ### Nearest large store 계산
# * 인구 밀도 데이터의 각 위치에 대해 가장 가까운 상권 찾기!

# %%
shops_gdf.head()
grid_df.head(5)

# 좌표계 5179(미터 단위 평면 좌표계) -> 4326(위도/경도) 좌표계로 변환
shops_gdf = shops_gdf.to_crs(epsg=4326)
grid_df = grid_df.to_crs(epsg=4326)
grid_df = calculate_centroids(grid_df)
# grid_df

# shops_gdf['geometry'] = shops_gdf.apply(lambda x: Point((float(x.y), float(x.x))), axis=1)
shops_gdf.head()
# Out:
# /tmp/ipykernel_2475765/1556320008.py:42: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   grid_df['centroid'] = grid_df.geometry.centroid
#    ê°ë°©ìì    ê´ë¦¬ë²í  ì¸íê°ì  ì¸íê°_1  ìì
# ìí  \
# 0     3170000  2.013317e+18  2013-09-06         NaN           1
# 1     3170000  2.012317e+18  2012-09-13         NaN           1
# 2     3140000  2.012314e+18  2012-04-05         NaN           1
# 3     3180000  2.001318e+18  1999-05-31         NaN           1
# 4     3210000  2.012321e+18  2012-04-24         NaN           1
#
#       ìì
# ì_1 ìì¸ìì    ìì¸ì_1 íì
# ì¼ì í´ì
# ìì  ...  \
# 0  ìì
# /ì ì          1  ì ììì
#        None       None  ...
# 1  ìì
# /ì ì          1  ì ììì
#        None       None  ...
# 2  ìì
# /ì ì          1  ì ììì
#        None       None  ...
# 3  ìì
# /ì ì          1  ì ììì
#        None       None  ...
# 4  ìì
# /ì ì          1  ì ììì
#        None       None  ...
#
#                 ì¬ì
# ì¥ë               ìµì¢
# ìì ë°ì´í°ê  \
# 0  ë§ë¦¬ì¤ìì¸ë  1ê´  2023/02/28 20:56:47.000          U
# 1  ë§ë¦¬ì¤ìì¸ë  3ê´  2023/02/28 21:05:56.000          U
# 2  ë¡¯ë°ìí¼ ëª©ë2ì   2023/03/09 09:25:54.000          U
# 3    ìë±í¬ì íµìê°  2023/03/09 15:28:54.000          U
# 4  ë¡¯ë°ìí¼ ë°©ë°°2ì   2023/03/13 17:40:32.000          U
#
#                 ë°ì´í_1                  ì
# íêµ¬ë             x  \
# 0  2022/12/03 00:03:00.000                ì¼íì¼í°  1.942285e+06
# 1  2022/12/03 00:03:00.000                ì¼íì¼í°  1.942315e+06
# 2  2022/12/02 23:01:00.000                êµ¬ë¶ìì  1.948525e+06
# 3  2022/12/02 23:01:00.000  ê·¸ ë°ì ëê·ëª¨ì í¬  1.947194e+06
# 4  2022/12/02 23:05:00.000                ëíë§í¸  1.943681e+06
#
#                y ì í¬êµ¬ë                    geometry       PPR
# 0  945553.391408       None   POINT (126.8842 37.47819)  0.000032
# 1  945370.100165       None  POINT (126.88213 37.47846)  0.000105
# 2  944344.700766       None  POINT (126.87006 37.53436)  0.000010
# 3  946191.860377       None  POINT (126.89106 37.52248)  0.000013
# 4  954598.673411       None  POINT (126.98641 37.49127)  0.000017
#
# [5 rows x 28 columns]

# %% [markdown]
# * 오류 : shops_gdf의 gemoetry 변환 시, 좌표계가 초기화 됨! -->

# %%
# shops_gdf['geometry'] = shops_gdf.apply(lambda x: Point((float(x.y), float(x.x))), axis=1)
# grid_df['centroid'] = grid_df.apply(lambda x: Point((float(x.centroid.y), float(x.centroid.x))), axis=1)

# shops_gdf.head()

# %%
from geopy.distance import geodesic

# 새로운 컬럼을 추가할 빈 데이터프레임 생성
grid_df['Nearest_dist'] = float('inf')  # 초기값을 무한대로 설정

# 인구 밀도 데이터의 각 위치에 대해 가장 가까운 상권 찾기
for _, row in tqdm(grid_df.iterrows(), total=grid_df.shape[0]):
 
    point = row['centroid']
    point_coords = (point.y, point.x) 
    
    # 각 상권 위치와 인구 밀도 위치 간의 거리 계산
    for idx, store_row in shops_gdf.iterrows():
        store_point = store_row['geometry']
        # Assuming 'geometry' is a shapely Point, extract latitude and longitude
        store_point_coords = (store_point.y, store_point.x)  # (latitude, longitude)
        distance = geodesic(point_coords, store_point_coords).kilometers
        
        # 가장 가까운 상권까지의 거리 업데이트
        if distance < grid_df.loc[_, 'Nearest_dist']:
            grid_df.loc[_, 'Nearest_dist'] = distance
# Out:
# 100%|██████████| 533/533 [01:11<00:00,  7.44it/s]

# %%
grid_df.head(10)
# Out:
#           gid       lbl      val  \
# 0  ë¤ì¬6453   8975.00   8975.0
# 1  ë¤ì¬5651  12141.00  12141.0
# 2  ë¤ì¬6157  28042.00  28042.0
# 3  ë¤ì¬5858  22857.00  22857.0
# 4  ë¤ì¬5347  12053.00  12053.0
# 5  ë¤ì¬5955  19321.00  19321.0
# 6  ë¤ì¬5748    903.00    903.0
# 7  ë¤ì¬7152  15448.00  15448.0
# 8  ë¤ì¬5961  28864.00  28864.0
# 9  ë¤ì¬6549   6816.00   6816.0
#
#                                             geometry  \
# 0  POLYGON ((127.0923 37.57567, 127.09225 37.5846...
# 1  POLYGON ((127.00183 37.5573, 127.00177 37.5663...
# 2  POLYGON ((127.05812 37.61161, 127.05806 37.620...
# 3  POLYGON ((127.02407 37.62049, 127.02401 37.629...
# 4  POLYGON ((126.96812 37.5211, 126.96805 37.5301...
# 5  POLYGON ((127.03557 37.59349, 127.03551 37.602...
# 6  POLYGON ((127.01332 37.53031, 127.01327 37.539...
# 7  POLYGON ((127.17162 37.56691, 127.17158 37.575...
# 8  POLYGON ((127.03523 37.64757, 127.03518 37.656...
# 9  POLYGON ((127.10382 37.53966, 127.10377 37.548...
#
#                      centroid  accessibility District_Name  Sales Average_age  \
# 0   POINT (127.09794 37.5802)       0.000000          면목7동    6.0        47.6
# 1  POINT (127.00746 37.56183)       0.000988           장충동    6.0        43.3
# 2  POINT (127.06376 37.61613)       0.000090          월계1동    6.0        46.0
# 3  POINT (127.02971 37.62502)       0.000044           송중동    6.0        47.6
# 4  POINT (126.97374 37.52563)       0.000135          한강로동    9.0        43.5
# 5   POINT (127.0412 37.59802)       0.000045          월곡2동    7.0        45.5
# 6  POINT (127.01895 37.53484)       0.000234           옥수동    8.0        43.9
# 7  POINT (127.17726 37.57143)       0.000000           강일동    7.0        43.1
# 8   POINT (127.04087 37.6521)       0.000029           창5동    7.0        46.5
# 9  POINT (127.10946 37.54419)       0.000019           광장동    9.0        40.9
#
#    Nearest_dist
# 0      1.204582
# 1      0.418711
# 2      0.251338
# 3      0.472307
# 4      0.734863
# 5      0.530838
# 6      0.644729
# 7      2.161967
# 8      0.314802
# 9      0.870210

# %% [markdown]
# ### Average distance to stores
# * 가장 가까운 상권 3개와의 거리 평균

# %%
# 새로운 컬럼을 추가할 빈 데이터프레임 생성
grid_df['Average_dist'] = float('inf')  # 초기값을 무한대로 설정

for _, row in tqdm(grid_df.iterrows(), total=grid_df.shape[0]):
 
    point = row['centroid']
    point_coords = (point.y, point.x) # (latitude, longitude) 
    
    distances = []
    # 각 상권 위치와 인구 밀도 위치 간의 거리 계산
    for idx, store_row in shops_gdf.iterrows():
        store_point = store_row['geometry']

        store_point_coords = (store_point.y, store_point.x)  # (latitude, longitude)
        distance = geodesic(point_coords, store_point_coords).kilometers
        distances.append(distance)
        
        # 가까운 순서대로 상권 거리 정렬
    distances.sort()
    avg_distance = sum(distances[:3])/3
    grid_df.loc[_, 'Average_dist'] = avg_distance
# Out:
# 100%|██████████| 533/533 [01:07<00:00,  7.90it/s]

# %%
grid_df.head(10)
# Out:
#           gid       lbl      val  \
# 0  ë¤ì¬6453   8975.00   8975.0
# 1  ë¤ì¬5651  12141.00  12141.0
# 2  ë¤ì¬6157  28042.00  28042.0
# 3  ë¤ì¬5858  22857.00  22857.0
# 4  ë¤ì¬5347  12053.00  12053.0
# 5  ë¤ì¬5955  19321.00  19321.0
# 6  ë¤ì¬5748    903.00    903.0
# 7  ë¤ì¬7152  15448.00  15448.0
# 8  ë¤ì¬5961  28864.00  28864.0
# 9  ë¤ì¬6549   6816.00   6816.0
#
#                                             geometry  \
# 0  POLYGON ((127.0923 37.57567, 127.09225 37.5846...
# 1  POLYGON ((127.00183 37.5573, 127.00177 37.5663...
# 2  POLYGON ((127.05812 37.61161, 127.05806 37.620...
# 3  POLYGON ((127.02407 37.62049, 127.02401 37.629...
# 4  POLYGON ((126.96812 37.5211, 126.96805 37.5301...
# 5  POLYGON ((127.03557 37.59349, 127.03551 37.602...
# 6  POLYGON ((127.01332 37.53031, 127.01327 37.539...
# 7  POLYGON ((127.17162 37.56691, 127.17158 37.575...
# 8  POLYGON ((127.03523 37.64757, 127.03518 37.656...
# 9  POLYGON ((127.10382 37.53966, 127.10377 37.548...
#
#                      centroid  accessibility District_Name  Sales Average_age  \
# 0   POINT (127.09794 37.5802)       0.000000          면목7동    6.0        47.6
# 1  POINT (127.00746 37.56183)       0.000988           장충동    6.0        43.3
# 2  POINT (127.06376 37.61613)       0.000090          월계1동    6.0        46.0
# 3  POINT (127.02971 37.62502)       0.000044           송중동    6.0        47.6
# 4  POINT (126.97374 37.52563)       0.000135          한강로동    9.0        43.5
# 5   POINT (127.0412 37.59802)       0.000045          월곡2동    7.0        45.5
# 6  POINT (127.01895 37.53484)       0.000234           옥수동    8.0        43.9
# 7  POINT (127.17726 37.57143)       0.000000           강일동    7.0        43.1
# 8   POINT (127.04087 37.6521)       0.000029           창5동    7.0        46.5
# 9  POINT (127.10946 37.54419)       0.000019           광장동    9.0        40.9
#
#    Nearest_dist  Average_dist  Store_num
# 0      1.204582      1.310634          0
# 1      0.418711      0.418711          0
# 2      0.251338      0.650095          0
# 3      0.472307      0.563379          0
# 4      0.734863      0.781898          0
# 5      0.530838      0.731857          0
# 6      0.644729      0.753232          0
# 7      2.161967      2.614594          0
# 8      0.314802      0.751128          0
# 9      0.870210      1.107812          0

# %% [markdown]
# ### Count of stores within 1 km
# * 서울시 내 근방 1Km 내에 있는 편의점 개수
# * (서울 시 내 편의점의 개수는 6964개)

# %% [markdown]
# ###

# %%
store_data = pd.read_csv(os.path.join(data_path, '서울시편의점정보.csv'))
store_data['X'], store_data['Y'] = transform_3857_to_4326(store_data['X'], store_data['Y'])

# %%
store_data.tail()
# Out:
#       OBJT_ID FCLTY_TY  FCLTY_CD  FCLTY_NM                 ADRES  \
# 6960    64320      편의점    509010     CJ편의점    서울특별시 동작구 신대방동 425
# 6961    64321      편의점    509010      GS25   서울특별시 성북구 종암동 70-14
# 6962    64322      편의점    509010      GS25      서울특별시 송파구 잠실동 10
# 6963    64323      편의점    509010        CU     서울특별시 강남구 세곡동 587
# 6964    64324      편의점    509010  위드미도림금빛점  서울특별시 영등포구 도림동 234-1
#
#                    RN_ADRES  TELNO  CTPRVN_CD   SGG_CD      EMD_CD          X  \
# 6960    서울특별시 동작구 보라매로5길 20    NaN       11.0  11590.0  11590109.0  37.493000
# 6961    서울특별시 성북구 종암로19길 24    NaN       11.0  11290.0  11290135.0  37.598175
# 6962      서울특별시 송파구 올림픽로 25    NaN       11.0  11710.0  11710101.0  37.516188
# 6963    서울특별시 강남구 헌릉로569길 9    NaN       11.0  11680.0  11680111.0  37.466785
# 6964  서울특별시 영등포구 도림로113길 17    NaN       11.0  11560.0  11560118.0  37.508813
#
#                Y  DATA_YR
# 6960  126.924318   2022.0
# 6961  127.033286   2022.0
# 6962  127.075928   2022.0
# 6963  127.100762   2022.0
# 6964  126.897895   2022.0

# %%
grid_df['Store_num'] = int(0)  # 초기값 0개

for _, row in tqdm(grid_df.iterrows(), total=grid_df.shape[0]):
 
    point = row['centroid']
    point_coords = (point.y, point.x) # (latitude, longitude) 
    
    store_num = 0
    # 각 편의점 위치와 인구 밀도 위치 간의 거리 계산
    for idx, store_row in store_data.iterrows():
        store_point_coords = (store_row['X'], store_row['Y'])  # (latitude, longitude)
        distance = geodesic(point_coords, store_point_coords).kilometers
        if distance <=1:
            store_num += 1
    
    grid_df.loc[_, 'Store_num'] = store_num
# Out:
# 100%|██████████| 533/533 [07:37<00:00,  1.16it/s]

# %%
grid_df.head()
# Out:
#           gid       lbl      val  \
# 0  ë¤ì¬6453   8975.00   8975.0
# 1  ë¤ì¬5651  12141.00  12141.0
# 2  ë¤ì¬6157  28042.00  28042.0
# 3  ë¤ì¬5858  22857.00  22857.0
# 4  ë¤ì¬5347  12053.00  12053.0
#
#                                             geometry  \
# 0  POLYGON ((127.0923 37.57567, 127.09225 37.5846...
# 1  POLYGON ((127.00183 37.5573, 127.00177 37.5663...
# 2  POLYGON ((127.05812 37.61161, 127.05806 37.620...
# 3  POLYGON ((127.02407 37.62049, 127.02401 37.629...
# 4  POLYGON ((126.96812 37.5211, 126.96805 37.5301...
#
#                      centroid  accessibility District_Name  Sales Average_age  \
# 0   POINT (127.09794 37.5802)       0.000000          면목7동    6.0        47.6
# 1  POINT (127.00746 37.56183)       0.000988           장충동    6.0        43.3
# 2  POINT (127.06376 37.61613)       0.000090          월계1동    6.0        46.0
# 3  POINT (127.02971 37.62502)       0.000044           송중동    6.0        47.6
# 4  POINT (126.97374 37.52563)       0.000135          한강로동    9.0        43.5
#
#    Nearest_dist  Average_dist  Store_num
# 0      1.204582      1.310634         21
# 1      0.418711      0.418711         84
# 2      0.251338      0.650095         43
# 3      0.472307      0.563379         50
# 4      0.734863      0.781898         27

# %% [markdown]
# ### Accessibility via public transport
# * 버스정류장 및 지하철의 접근성(반경 500M 내)

# %%
bus_station = pd.read_csv(os.path.join(data_path, '2024년1~4월1일기준_서울시버스정류소위치정보.csv'), encoding='cp949')
bus_station.tail()
# Out:
#         STDR_DE    NODE_ID  STTN_NO      STTN_NM     CRDNT_X    CRDNT_Y  \
# 50460  20240401  124000334    25995        우성아파트  127.139338  37.550386
# 50461  20240401  124000333    25996        우성아파트  127.140046  37.550643
# 50462  20240401  124000332    25997         조일약국  127.123596  37.533630
# 50463  20240401  124000331    25998         성내시장  127.125497  37.536155
# 50464  20240401  124000330    25999  천호우체국.로데오거리  127.127337  37.540343
#
#        STTN_TY  Unnamed: 7
# 50460        0         NaN
# 50461        0         NaN
# 50462        0         NaN
# 50463        0         NaN
# 50464        0         NaN

# %%
grid_df['Bus_station_num'] = int(0)  # 초기값 0개

for _, row in tqdm(grid_df.iterrows(), total=grid_df.shape[0]):
 
    point = row['centroid']
    point_coords = (point.y, point.x) # (latitude, longitude) 
    
    bus_num = 0
    # 각 편의점 위치와 인구 밀도 위치 간의 거리 계산
    for idx, bus_row in bus_station.iterrows():
        bus_point_coords = (bus_row['CRDNT_Y'], bus_row['CRDNT_X'])  # (latitude, longitude)
        distance = geodesic(point_coords, bus_point_coords).kilometers
        if distance <=0.5:
            bus_num += 1
    
    grid_df.loc[_, 'Bus_station_num'] = bus_num
# Out:
# 100%|██████████| 533/533 [55:18<00:00,  6.23s/it]

# %%
# grid_df.to_csv('1st_data.csv', index=False)
grid_df.head()
# Out:
#           gid       lbl       val  \
# 0  ë¤ì¬6453   8975.00  0.199884
# 1  ë¤ì¬5651  12141.00  0.270458
# 2  ë¤ì¬6157  28042.00  0.624908
# 3  ë¤ì¬5858  22857.00  0.509329
# 4  ë¤ì¬5347  12053.00  0.268496
#
#                                             geometry  \
# 0  POLYGON ((127.0923 37.57567, 127.09225 37.5846...
# 1  POLYGON ((127.00183 37.5573, 127.00177 37.5663...
# 2  POLYGON ((127.05812 37.61161, 127.05806 37.620...
# 3  POLYGON ((127.02407 37.62049, 127.02401 37.629...
# 4  POLYGON ((126.96812 37.5211, 126.96805 37.5301...
#
#                      centroid  accessibility District_Name  Sales  \
# 0   POINT (127.09794 37.5802)       0.000000          면목7동   0.25
# 1  POINT (127.00746 37.56183)       0.651324           장충동   0.25
# 2  POINT (127.06376 37.61613)       0.059375          월계1동   0.25
# 3  POINT (127.02971 37.62502)       0.029107           송중동   0.25
# 4  POINT (126.97374 37.52563)       0.088898          한강로동   1.00
#
#    Average_age  Nearest_dist  Average_dist  Store_num  Bus_station_num  \
# 0     0.643275      0.295605      0.307690   0.166667         0.057143
# 1     0.391813      0.099731      0.083780   0.666667         0.328571
# 2     0.549708      0.058014      0.141867   0.341270         0.657143
# 3     0.643275      0.113090      0.120098   0.396825         0.542857
# 4     0.403509      0.178530      0.174955   0.214286         0.057143
#
#    Subway_station_num  total_sum total_sum_category
# 0                0.00   1.920264                Low
# 1                1.00   3.742344          Very High
# 2                0.25   2.932285               High
# 3                0.25   2.854581               High
# 4                0.25   2.635817             Medium

# %%
subway_station = pd.read_csv(os.path.join(data_path, '서울교통공사_1_8호선 역사 좌표(위경도) 정보_20231031.csv'), encoding='cp949')
subway_station.tail()
# Out:
#       연번  호선  고유역번호(외부역코드)      역명         위도          경도        작성일자
# 271  272   8          2823  남한산성입구  37.451568  127.159845  1996-10-31
# 272  273   8          2824   단대오거리  37.445057  127.156735  1996-12-28
# 273  274   8          2825      신흥  37.440952  127.147590  1996-12-28
# 274  275   8          2826      수진  37.437575  127.140936  1996-12-28
# 275  276   8          2827      모란  37.433888  127.129921  1996-11-30

# %%
grid_df['Subway_station_num'] = int(0)  # 초기값 0개

for _, row in tqdm(grid_df.iterrows(), total=grid_df.shape[0]):
 
    point = row['centroid']
    point_coords = (point.y, point.x) # (latitude, longitude) 
    
    sub_num = 0
    # 각 편의점 위치와 인구 밀도 위치 간의 거리 계산
    for idx, sub_row in subway_station.iterrows():
        sub_point_coords = (sub_row['위도'], sub_row['경도'])  # (latitude, longitude)
        distance = geodesic(point_coords, sub_point_coords).kilometers
        if distance <=0.5:
            sub_num += 1
    
    grid_df.loc[_, 'Subway_station_num'] = sub_num
# Out:
# 100%|██████████| 533/533 [00:18<00:00, 28.69it/s]

# %%
grid_df.to_csv('Food_desert_raw_data.csv')
# Out:
#           gid       lbl      val  \
# 0  ë¤ì¬6453   8975.00   8975.0
# 1  ë¤ì¬5651  12141.00  12141.0
# 2  ë¤ì¬6157  28042.00  28042.0
# 3  ë¤ì¬5858  22857.00  22857.0
# 4  ë¤ì¬5347  12053.00  12053.0
#
#                                             geometry  \
# 0  POLYGON ((127.0923 37.57567, 127.09225 37.5846...
# 1  POLYGON ((127.00183 37.5573, 127.00177 37.5663...
# 2  POLYGON ((127.05812 37.61161, 127.05806 37.620...
# 3  POLYGON ((127.02407 37.62049, 127.02401 37.629...
# 4  POLYGON ((126.96812 37.5211, 126.96805 37.5301...
#
#                      centroid  accessibility District_Name  Sales Average_age  \
# 0   POINT (127.09794 37.5802)       0.000000          면목7동    6.0        47.6
# 1  POINT (127.00746 37.56183)       0.000988           장충동    6.0        43.3
# 2  POINT (127.06376 37.61613)       0.000090          월계1동    6.0        46.0
# 3  POINT (127.02971 37.62502)       0.000044           송중동    6.0        47.6
# 4  POINT (126.97374 37.52563)       0.000135          한강로동    9.0        43.5
#
#    Nearest_dist  Average_dist  Store_num  Bus_station_num  Subway_station_num
# 0      1.204582      1.310634         21               16                   0
# 1      0.418711      0.418711         84               92                   4
# 2      0.251338      0.650095         43              184                   1
# 3      0.472307      0.563379         50              152                   1
# 4      0.734863      0.781898         27               16                   1

# %% [markdown]
# ### 열 속성 값 정규화
# * 0~1 사이 값으로 scale 조정

# %%
grid_df['Average_age'] = grid_df['Average_age'].astype(float)

# %%
from sklearn.preprocessing import MinMaxScaler

# Instantiate the scaler
scaler = MinMaxScaler()

# Assuming grid_df is your DataFrame and you want to scale all numerical columns
negative_columns = ['Average_age', 'Nearest_dist', 'Average_dist']
positive_columns = ['accessibility', 'Sales', 'Store_num', 'Bus_station_num', 'Subway_station_num']
# Fit and transform the data
for col in positive_columns:
    for idx, row in grid_df.iterrows():
        if row[col] != 0:
            grid_df.at[idx, col] = 1/row[col]


grid_df[negative_columns] = scaler.fit_transform(grid_df[negative_columns])
grid_df[positive_columns] = scaler.fit_transform(grid_df[positive_columns])

grid_df.head()
# Out:
#           gid       lbl       val  \
# 0  ë¤ì¬6453   8975.00  0.199884
# 1  ë¤ì¬5651  12141.00  0.270458
# 2  ë¤ì¬6157  28042.00  0.624908
# 3  ë¤ì¬5858  22857.00  0.509329
# 4  ë¤ì¬5347  12053.00  0.268496
#
#                                             geometry  \
# 0  POLYGON ((127.0923 37.57567, 127.09225 37.5846...
# 1  POLYGON ((127.00183 37.5573, 127.00177 37.5663...
# 2  POLYGON ((127.05812 37.61161, 127.05806 37.620...
# 3  POLYGON ((127.02407 37.62049, 127.02401 37.629...
# 4  POLYGON ((126.96812 37.5211, 126.96805 37.5301...
#
#                      centroid  accessibility District_Name  Sales  \
# 0   POINT (127.09794 37.5802)       0.000000          면목7동   0.25
# 1  POINT (127.00746 37.56183)       0.651324           장충동   0.25
# 2  POINT (127.06376 37.61613)       0.059375          월계1동   0.25
# 3  POINT (127.02971 37.62502)       0.029107           송중동   0.25
# 4  POINT (126.97374 37.52563)       0.088898          한강로동   1.00
#
#    Average_age  Nearest_dist  Average_dist  Store_num  Bus_station_num  \
# 0     0.643275      0.295605      0.307690   0.166667         0.057143
# 1     0.391813      0.099731      0.083780   0.666667         0.328571
# 2     0.549708      0.058014      0.141867   0.341270         0.657143
# 3     0.643275      0.113090      0.120098   0.396825         0.542857
# 4     0.403509      0.178530      0.174955   0.214286         0.057143
#
#    Subway_station_num
# 0                0.00
# 1                1.00
# 2                0.25
# 3                0.25
# 4                0.25

# %%
total_columns = ['Average_age', 'Nearest_dist', 'Average_dist', 'accessibility', 'Sales', 'Store_num', 'Bus_station_num', 'Subway_station_num']
grid_df['total_sum'] = grid_df[total_columns].sum(axis=1)
grid_df['total_sum_category'] = pd.cut(grid_df['total_sum'], bins=4, labels=['Low', 'Medium', 'High', 'Very High'])

# %%
grid_df.head()
# Out:
#           gid       lbl       val  \
# 0  ë¤ì¬6453   8975.00  0.199884
# 1  ë¤ì¬5651  12141.00  0.270458
# 2  ë¤ì¬6157  28042.00  0.624908
# 3  ë¤ì¬5858  22857.00  0.509329
# 4  ë¤ì¬5347  12053.00  0.268496
#
#                                             geometry  accessibility  \
# 0  POLYGON ((127.0923 37.57567, 127.09225 37.5846...       0.000000
# 1  POLYGON ((127.00183 37.5573, 127.00177 37.5663...       0.651324
# 2  POLYGON ((127.05812 37.61161, 127.05806 37.620...       0.059375
# 3  POLYGON ((127.02407 37.62049, 127.02401 37.629...       0.029107
# 4  POLYGON ((126.96812 37.5211, 126.96805 37.5301...       0.088898
#
#   District_Name  Sales  Average_age  Nearest_dist  Average_dist  Store_num  \
# 0          면목7동   0.25     0.643275      0.295605      0.307690   6.000000
# 1           장충동   0.25     0.391813      0.099731      0.083780   1.500000
# 2          월계1동   0.25     0.549708      0.058014      0.141867   2.930233
# 3           송중동   0.25     0.643275      0.113090      0.120098   2.520000
# 4          한강로동   1.00     0.403509      0.178530      0.174955   4.666667
#
#    Bus_station_num  Subway_station_num  total_sum total_sum_category
# 0        17.500000                 0.0  25.196454                Low
# 1         3.043478                 1.0   7.290584                Low
# 2         1.521739                 4.0  10.135844                Low
# 3         1.842105                 4.0  10.027003                Low
# 4        17.500000                 4.0  28.281055                Low

# %% [markdown]
# ### Folium map 시각화

# %%
import folium
import geopandas as gpd
from folium import LayerControl
from branca.colormap import linear

# grid_df = grid_df.drop(columns=['centroid'])
geojson_data = grid_df.to_json()

# Create a base map
m = folium.Map(location=[37.57567, 127.0923], zoom_start=12)

# Define the color scale for the choropleth map
color_scale = linear.YlGnBu_09.scale(grid_df['total_sum'].min(), grid_df['total_sum'].max())
color_scale.caption = 'Total Sum Intensity'

# Function to apply color scale
def style_function(feature):
    total_sum = feature['properties']['total_sum']
    return {
        'fillColor': color_scale(total_sum),
        'color': 'black',
        'weight': 0.5,
        'fillOpacity': 0.5,
        'lineOpacity': 0.1
    }

# Add GeoJson layer
folium.GeoJson(
    geojson_data,
    style_function=style_function,
    name='choropleth',
    tooltip=folium.GeoJsonTooltip(fields=['val', 'total_sum'], aliases=['ID', 'Total Sum'])
).add_to(m)

# Add color scale to the map
color_scale.add_to(m)

# Add layer control
LayerControl().add_to(m)

# Save or display the map
m.save('map.html')  # 지도 저장
m  # Jupyter Notebook에서 지도 표시
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d4dc2ed21cd17b25897fec36817f597a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d4dc2ed21cd17b25897fec36817f597a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d4dc2ed21cd17b25897fec36817f597a = L.map(
#                 &quot;map_d4dc2ed21cd17b25897fec36817f597a&quot;,
#                 {
#                     center: [37.57567, 127.0923],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_6a9c4e36230f3d596451dffe0617ef2c = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_6a9c4e36230f3d596451dffe0617ef2c.addTo(map_d4dc2ed21cd17b25897fec36817f597a);
#
#
#         function geo_json_e3a621e8bbeb58c40971da42851abcb3_styler(feature) {
#             switch(feature.id) {
#                 case &quot;0&quot;: case &quot;165&quot;: case &quot;362&quot;: case &quot;423&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#d6efb3ff&quot;, &quot;fillOpacity&quot;: 0.5, &quot;lineOpacity&quot;: 0.1, &quot;weight&quot;: 0.5};
#                 case &quot;1&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#182a7bff&quot;, &quot;fillOpacity&quot;: 0.5, &quot;lineOpacity&quot;: 0.1, &quot;weight&quot;: 0.5};
#                 case &quot;2&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#2397c1ff&quot;, &quot;fillOpacity&quot;: 0.5, &quot;lineOpacity&quot;: 0.1, &quot;weight&quot;: 0.5};
#                 case &quot;3&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#2ca0c2ff&quot;, &quot;fillOpacity&quot;: 0.5, &quot;lineOpacity&quot;: 0.1, &quot;weight&quot;: 0.5};
#                 case &quot;4&quot;: case &quot;170&quot;: case &quot;466&quot;: case &quot;469&quot;: case &quot;483&quot;: case &quot;606&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#48b9c3ff&quot;, &quot;fillOpacity&quot;: 0.5, &quot;lineOpacity&quot;: 0.1, &quot;weight&quot;: 0.5};
#                 case &quot;5&quot;: case &quot;140&quot;: case &quot;516&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#6bc6beff&quot;, &quot;fillOpacity&quot;: 0.5, &quot;lineOpacity&quot;: 0.1, &quot;weight&quot;: 0.5};
#                 case &quot;6&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#ebf8b1ff&quot;, &quot;fillOpacity&quot;: 0.5, &quot;lineOpacity&quot;: 0.1, &quot;weight&quot;: 0.5};
#                 case &quot;7&quot;: case &quot;35&quot;: case &quot;254&quot;: case &quot;279&quot;: case &quot;311&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#3cb1c4ff&quot;, &quot;fillOpacity&quot;: 0.5, &quot;lineOpacity&quot;: 0.1, &quot;weight&quot;: 0.5};
#                 case &quot;8&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#2498c1ff&quot;, &quot;fillOpacity&quot;: 0.5, &quot;lineOpacity&quot;: 0.1, &quot;weight&quot;: 0.5};
#                 case &quot;9&quot;: case &quot;439&quot;: case &quot;497&quot;: case &quot;498&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#a1dbb8ff&quot;, &quot;fillOpacity&quot;: 0.5, &quot;lineOpacity&quot;: 0.1, &quot;weight&quot;: 0.5};
#                 case &quot;10&quot;: case &quot;298&quot;: case &quot;331&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#d3eeb3ff&quot;, &quot;fillOpacity&quot;: 0.5, &quot;lineOpacity&quot;: 0.1, &quot;weight&quot;: 0.5};
#                 case &quot;11&quot;: case &quot;34&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#4dbbc3ff&quot;, &quot;fillOpacity&quot;: 0.5, &quot;lineOpacity&quot;: 0.1, &quot;weight&quot;: 0.5};
#                 case &quot;12&quot;: case &quot;110&quot;: case &quot;227&quot;:
#                     return {&quot;color&quot;
